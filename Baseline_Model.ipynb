# %%
# Import Required Libraries
import os
import random
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from transformers import BertModel, BertTokenizer, get_scheduler
from torch.optim import AdamW
from datasets import load_dataset
from collections import defaultdict
from sklearn.metrics import accuracy_score, mean_squared_error
from scipy.stats import pearsonr
import numpy as np

# %%
#Set Environment and Seed
os.environ["WANDB_DISABLED"] = "true"
random.seed(42)
torch.manual_seed(42)

# %%
#Load Pretrained Tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# %%
# Tokenize Each Task Dataset
# Each function takes a single sample (dict) and applies the tokenizer

def tokenize_sst(sample):
    return tokenizer(sample["sentence"], padding="max_length", truncation=True, max_length=128)

def tokenize_qqp(sample):
    return tokenizer(sample["question1"], sample["question2"], padding="max_length", truncation=True, max_length=128)

def tokenize_sts(sample):
    return tokenizer(sample["sentence1"], sample["sentence2"], padding="max_length", truncation=True, max_length=128)

# %%
# Load and Prepare Datasets
datasets = {
    "sst": load_dataset("glue", "sst2"),
    "qqp": load_dataset("glue", "qqp"),
    "sts": load_dataset("glue", "stsb"),
}

tokenized = {
    "sst": datasets["sst"].map(tokenize_sst, batched=True),
    "qqp": datasets["qqp"].map(tokenize_qqp, batched=True),
    "sts": datasets["sts"].map(tokenize_sts, batched=True),
}

for task in tokenized:
    if task == "sst":
        tokenized[task] = tokenized[task].remove_columns(["sentence", "idx"])
    elif task == "qqp":
        tokenized[task] = tokenized[task].remove_columns(["question1", "question2", "idx"])
    elif task == "sts":
        tokenized[task] = tokenized[task].remove_columns(["sentence1", "sentence2", "idx"])
    tokenized[task] = tokenized[task].rename_column("label", "labels")
    tokenized[task].set_format("torch")
# Out:
# Map: 100%|██████████| 67349/67349 [00:12<00:00, 5512.85 examples/s]
# Map: 100%|██████████| 872/872 [00:00<00:00, 3487.91 examples/s]
# Map: 100%|██████████| 1821/1821 [00:00<00:00, 3887.97 examples/s]
# Map:   0%|          | 1000/363846 [00:00<02:05, 2902.50 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:   1%|          | 3000/363846 [00:01<02:01, 2958.69 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:   4%|▍         | 14000/363846 [00:04<01:56, 3011.91 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:   4%|▍         | 15000/363846 [00:05<01:55, 3008.13 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:   4%|▍         | 16000/363846 [00:05<01:55, 2998.75 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:   7%|▋         | 24000/363846 [00:08<01:57, 2881.25 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:   8%|▊         | 28000/363846 [00:09<01:46, 3153.78 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:   9%|▊         | 31000/363846 [00:10<01:47, 3098.53 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  10%|▉         | 36000/363846 [00:11<01:44, 3137.68 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  12%|█▏        | 43000/363846 [00:14<01:44, 3065.36 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  14%|█▎        | 50000/363846 [00:16<01:43, 3046.06 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  15%|█▍        | 53000/363846 [00:17<01:42, 3041.66 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  17%|█▋        | 62000/363846 [00:20<01:42, 2956.94 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  17%|█▋        | 63000/363846 [00:21<01:44, 2888.46 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  18%|█▊        | 65000/363846 [00:21<01:41, 2940.85 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  19%|█▊        | 68000/363846 [00:22<01:50, 2689.15 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  20%|█▉        | 71000/363846 [00:24<01:42, 2864.67 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:
examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  53%|█████▎    | 209000/390965 [01:15<01:03, 2867.82 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  54%|█████▎    | 210000/390965 [01:16<01:03, 2859.80 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  56%|█████▌    | 218000/390965 [01:18<00:56, 3040.73 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  57%|█████▋    | 222000/390965 [01:20<00:56, 2976.96 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  59%|█████▉    | 231000/390965 [01:23<00:57, 2789.68 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  60%|█████▉    | 233000/390965 [01:23<00:59, 2633.18 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  61%|██████    | 237000/390965 [01:25<00:59, 2583.39 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  63%|██████▎   | 246000/390965 [01:28<00:49, 2929.69 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  63%|██████▎   | 247000/390965 [01:28<00:49, 2929.42 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  65%|██████▍   | 253000/390965 [01:30<00:47, 2912.03 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  66%|██████▌   | 258000/390965 [01:32<00:43, 3059.64 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  66%|██████▌   | 259000/390965 [01:32<00:43, 3018.55 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  68%|██████▊   | 265000/390965 [01:34<00:42, 2976.35 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  70%|███████   | 275000/390965 [01:38<00:40, 2871.55 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  71%|███████▏  | 279000/390965 [01:39<00:39, 2833.69 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  74%|███████▍  | 291000/390965 [01:44<00:33, 2946.58 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  75%|███████▌  | 294000/390965 [01:45<00:33, 2915.00 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  76%|███████▌  | 297000/390965 [01:46<00:32, 2892.63 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  76%|███████▌  | 298000/390965 [01:46<00:32, 2894.96 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  76%|███████▋  | 299000/390965 [01:46<00:32, 2818.54 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  78%|███████▊  | 304000/390965 [01:48<00:34, 2556.52 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  78%|███████▊  | 305000/390965 [01:49<00:32, 2633.95 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  78%|███████▊  | 306000/390965 [01:49<00:31, 2694.56 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  81%|████████  | 317000/390965 [01:53<00:25, 2903.76 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  82%|████████▏ | 321000/390965 [01:54<00:24, 2895.15 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  86%|████████▌ | 336000/390965 [02:00<00:19, 2874.39 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  88%|████████▊ | 344000/390965 [02:03<00:16, 2771.44 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  88%|████████▊ | 345000/390965 [02:03<00:16, 2795.30 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  95%|█████████▍| 370000/390965 [02:12<00:07, 2635.04 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  96%|█████████▋| 377000/390965 [02:14<00:04, 2951.20 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  97%|█████████▋| 380000/390965 [02:15<00:03, 2917.13 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  98%|█████████▊| 383000/390965 [02:16<00:02, 2958.43 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map:  98%|█████████▊| 384000/390965 [02:16<00:02, 2922.36 examples/s]Be aware, overflowing tokens are not returned for the setting you have chosen, i.e. sequence pairs with the 'longest_first' truncation strategy. So the returned list will always be empty even if some tokens have been removed.
# Map: 100%|██████████| 390965/390965 [02:19<00:00, 2804.30 examples/s]
# Map: 100%|██████████| 5749/5749 [00:01<00:00, 3093.30 examples/s]
# Map: 100%|██████████| 1500/1500 [00:00<00:00, 2724.70 examples/s]
# Map: 100%|██████████| 1379/1379 [00:00<00:00, 2203.30 examples/s]

# %%
# Define Multitask BERT Model Class
class MultiTaskBERT(nn.Module):
    def __init__(self):
        super().__init__()
        self.bert = BertModel.from_pretrained("bert-base-uncased")
        self.dropout = nn.Dropout(0.1)
        self.sst_head = nn.Linear(768, 2)           # classification
        self.qqp_head = nn.Linear(768, 2)           # classification
        self.sts_head = nn.Sequential(              # regression
            nn.Linear(768, 1),
            nn.Sigmoid()
        )

    def forward(self, input_ids, attention_mask, task):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        cls_output = self.dropout(outputs.pooler_output)
        if task == "sst":
            return self.sst_head(cls_output)
        elif task == "qqp":
            return self.qqp_head(cls_output)
        elif task == "sts":
            return self.sts_head(cls_output) * 5  # scale to [0, 5]

# %%
#  Task-Specific Dataloaders
batch_size = 16
dataloaders = {
    task: DataLoader(tokenized[task]["train"], batch_size=batch_size, shuffle=True)
    for task in tokenized
}

task_list = list(dataloaders.keys())
task_sizes = {task: len(dataloaders[task].dataset) for task in task_list}
task_probs = [task_sizes[task] / sum(task_sizes.values()) for task in task_list]

# %%
# Initialize Model and Optimizer
model = MultiTaskBERT()
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
optimizer = AdamW(model.parameters(), lr=2e-5)
scheduler = get_scheduler("linear", optimizer=optimizer, num_warmup_steps=0, num_training_steps=10000)

# %%
# Training Loop
num_epochs = 3
model.train()

task_iterators = {task: iter(loader) for task, loader in dataloaders.items()}

for epoch in range(num_epochs):
    for step in range(10000):  # define total steps or batches
        task = random.choices(task_list, weights=task_probs, k=1)[0]
        try:
            batch = next(task_iterators[task])
        except StopIteration:
            task_iterators[task] = iter(dataloaders[task])
            batch = next(task_iterators[task])

        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)
        labels = batch["labels"].to(device)

        outputs = model(input_ids=input_ids, attention_mask=attention_mask, task=task)

        if task in ["sst", "qqp"]:
            loss_fn = nn.CrossEntropyLoss()
            loss = loss_fn(outputs, labels)
        elif task == "sts":
            loss_fn = nn.MSELoss()
            loss = loss_fn(outputs.view(-1), labels.view(-1))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        scheduler.step()

        if step % 100 == 0:
            print(f"Epoch {epoch+1} | Step {step} | Task: {task} | Loss: {loss.item():.4f}")
# Out:
# Epoch 1 | Step 0 | Task: qqp | Loss: 0.7150
# Epoch 1 | Step 100 | Task: sst | Loss: 0.7202
# Epoch 1 | Step 200 | Task: qqp | Loss: 0.4777
# Epoch 1 | Step 300 | Task: qqp | Loss: 0.4509
# Epoch 1 | Step 400 | Task: qqp | Loss: 0.4325
# Epoch 1 | Step 500 | Task: qqp | Loss: 0.8232
# Epoch 1 | Step 600 | Task: sst | Loss: 0.2647
# Epoch 1 | Step 700 | Task: qqp | Loss: 0.5158
# Epoch 1 | Step 800 | Task: qqp | Loss: 0.4877
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 30
#      27     loss = loss_fn(outputs.view(-1), labels.view(-1))
#      29 optimizer.zero_grad()
# ---> 30 loss.backward()
#      31 optimizer.step()
#      32 scheduler.step()
#
# File c:\Users\ragha\anaconda3\envs\Python9\lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\Users\ragha\anaconda3\envs\Python9\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Users\ragha\anaconda3\envs\Python9\lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
# Save Final Multitask Model
save_path = "./multitask_bert_model"
os.makedirs(save_path, exist_ok=True)
torch.save(model.state_dict(), f"{save_path}/model.pt")
tokenizer.save_pretrained(save_path)
print("✅ Training complete and model saved.")
